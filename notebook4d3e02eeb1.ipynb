# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/json-data/dataset_rsicd.json
# /kaggle/input/image-data/RSICD_images/port_26.jpg
# /kaggle/input/image-data/RSICD_images/industrial_169.jpg
# /kaggle/input/image-data/RSICD_images/center_68.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_212.jpg
# /kaggle/input/image-data/RSICD_images/00767.jpg
# /kaggle/input/image-data/RSICD_images/playground_264.jpg
# /kaggle/input/image-data/RSICD_images/forest_205.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_317.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_323.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_77.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_223.jpg
# /kaggle/input/image-data/RSICD_images/farmland_318.jpg
# /kaggle/input/image-data/RSICD_images/00266.jpg
# /kaggle/input/image-data/RSICD_images/center_102.jpg
# /kaggle/input/image-data/RSICD_images/center_189.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_197.jpg
# /kaggle/input/image-data/RSICD_images/parking_332.jpg
# /kaggle/input/image-data/RSICD_images/pond_317.jpg
# /kaggle/input/image-data/RSICD_images/00847.jpg
# /kaggle/input/image-data/RSICD_images/airport_118.jpg
# /kaggle/input/image-data/RSICD_images/00822.jpg
# /kaggle/input/image-data/RSICD_images/00614.jpg
# /kaggle/input/image-data/RSICD_images/meadow_248.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_32.jpg
# /kaggle/input/image-data/RSICD_images/center_198.jpg
# /kaggle/input/image-data/RSICD_images/square_207.jpg
# /kaggle/input/image-data/RSICD_images/industrial_84.jpg
# /kaggle/input/image-data/RSICD_images/00878.jpg
# /kaggle/input/image-data/RSICD_images/bridge_261.jpg
# /kaggle/input/image-data/RSICD_images/stadium_13.jpg
# /kaggle/input/image-data/RSICD_images/playground_195.jpg
# /kaggle/input/image-data/RSICD_images/desert_157.jpg
# /kaggle/input/image-data/RSICD_images/pond_309.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_209.jpg
# /kaggle/input/image-data/RSICD_images/industrial_296.jpg
# /kaggle/input/image-data/RSICD_images/church_34.jpg
# /kaggle/input/image-data/RSICD_images/resort_118.jpg
# /kaggle/input/image-data/RSICD_images/desert_64.jpg
# /kaggle/input/image-data/RSICD_images/parking_227.jpg
# /kaggle/input/image-data/RSICD_images/meadow_203.jpg
# /kaggle/input/image-data/RSICD_images/square_267.jpg
# /kaggle/input/image-data/RSICD_images/commercial_297.jpg
# /kaggle/input/image-data/RSICD_images/parking_6.jpg
# /kaggle/input/image-data/RSICD_images/center_246.jpg
# /kaggle/input/image-data/RSICD_images/square_114.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_226.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_252.jpg
# /kaggle/input/image-data/RSICD_images/industrial_22.jpg
# /kaggle/input/image-data/RSICD_images/park_6.jpg
# /kaggle/input/image-data/RSICD_images/river_248.jpg
# /kaggle/input/image-data/RSICD_images/port_240.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_33.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_67.jpg
# /kaggle/input/image-data/RSICD_images/playground_261.jpg
# /kaggle/input/image-data/RSICD_images/industrial_112.jpg
# /kaggle/input/image-data/RSICD_images/industrial_90.jpg
# /kaggle/input/image-data/RSICD_images/mountain_59.jpg
# /kaggle/input/image-data/RSICD_images/meadow_117.jpg
# /kaggle/input/image-data/RSICD_images/airport_343.jpg
# /kaggle/input/image-data/RSICD_images/00091.jpg
# /kaggle/input/image-data/RSICD_images/playground_244.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_332.jpg
# /kaggle/input/image-data/RSICD_images/beach_389.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_178.jpg
# /kaggle/input/image-data/RSICD_images/desert_197.jpg
# /kaggle/input/image-data/RSICD_images/00838.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_86.jpg
# /kaggle/input/image-data/RSICD_images/bareland_278.jpg
# /kaggle/input/image-data/RSICD_images/forest_152.jpg
# /kaggle/input/image-data/RSICD_images/playground_106.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_419.jpg
# /kaggle/input/image-data/RSICD_images/playground_84.jpg
# /kaggle/input/image-data/RSICD_images/pond_157.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_166.jpg
# /kaggle/input/image-data/RSICD_images/00296.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_23.jpg
# /kaggle/input/image-data/RSICD_images/pond_224.jpg
# /kaggle/input/image-data/RSICD_images/mountain_154.jpg
# /kaggle/input/image-data/RSICD_images/commercial_99.jpg
# /kaggle/input/image-data/RSICD_images/pond_288.jpg
# /kaggle/input/image-data/RSICD_images/desert_38.jpg
# /kaggle/input/image-data/RSICD_images/park_229.jpg
# /kaggle/input/image-data/RSICD_images/desert_75.jpg
# /kaggle/input/image-data/RSICD_images/bridge_229.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_240.jpg
# /kaggle/input/image-data/RSICD_images/beach_320.jpg
# /kaggle/input/image-data/RSICD_images/playground_184.jpg
# /kaggle/input/image-data/RSICD_images/river_337.jpg
# /kaggle/input/image-data/RSICD_images/resort_56.jpg
# /kaggle/input/image-data/RSICD_images/resort_271.jpg
# /kaggle/input/image-data/RSICD_images/industrial_338.jpg
# /kaggle/input/image-data/RSICD_images/bareland_94.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_240.jpg
# /kaggle/input/image-data/RSICD_images/00219.jpg
# /kaggle/input/image-data/RSICD_images/forest_36.jpg
# /kaggle/input/image-data/RSICD_images/resort_272.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_220.jpg
# /kaggle/input/image-data/RSICD_images/resort_10.jpg
# /kaggle/input/image-data/RSICD_images/farmland_5.jpg
# /kaggle/input/image-data/RSICD_images/church_125.jpg
# /kaggle/input/image-data/RSICD_images/meadow_153.jpg
# /kaggle/input/image-data/RSICD_images/airport_104.jpg
# /kaggle/input/image-data/RSICD_images/bridge_53.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_143.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_49.jpg
# /kaggle/input/image-data/RSICD_images/pond_372.jpg
# /kaggle/input/image-data/RSICD_images/mountain_257.jpg
# /kaggle/input/image-data/RSICD_images/mountain_317.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_156.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_197.jpg
# /kaggle/input/image-data/RSICD_images/commercial_65.jpg
# /kaggle/input/image-data/RSICD_images/desert_180.jpg
# /kaggle/input/image-data/RSICD_images/playground_351.jpg
# /kaggle/input/image-data/RSICD_images/industrial_336.jpg
# /kaggle/input/image-data/RSICD_images/mountain_223.jpg
# /kaggle/input/image-data/RSICD_images/square_326.jpg
# /kaggle/input/image-data/RSICD_images/pond_315.jpg
# /kaggle/input/image-data/RSICD_images/airport_279.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_134.jpg
# /kaggle/input/image-data/RSICD_images/church_179.jpg
# /kaggle/input/image-data/RSICD_images/00130.jpg
# /kaggle/input/image-data/RSICD_images/00460.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_51.jpg
# /kaggle/input/image-data/RSICD_images/airport_185.jpg
# /kaggle/input/image-data/RSICD_images/00254.jpg
# /kaggle/input/image-data/RSICD_images/beach_216.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_139.jpg
# /kaggle/input/image-data/RSICD_images/pond_139.jpg
# /kaggle/input/image-data/RSICD_images/parking_264.jpg
# /kaggle/input/image-data/RSICD_images/bridge_314.jpg
# /kaggle/input/image-data/RSICD_images/00884.jpg
# /kaggle/input/image-data/RSICD_images/school_30.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_299.jpg
# /kaggle/input/image-data/RSICD_images/00706.jpg
# /kaggle/input/image-data/RSICD_images/pond_68.jpg
# /kaggle/input/image-data/RSICD_images/00896.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_67.jpg
# /kaggle/input/image-data/RSICD_images/pond_215.jpg
# /kaggle/input/image-data/RSICD_images/parking_131.jpg
# /kaggle/input/image-data/RSICD_images/commercial_335.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_381.jpg
# /kaggle/input/image-data/RSICD_images/00160.jpg
# /kaggle/input/image-data/RSICD_images/industrial_324.jpg
# /kaggle/input/image-data/RSICD_images/industrial_381.jpg
# /kaggle/input/image-data/RSICD_images/bridge_217.jpg
# /kaggle/input/image-data/RSICD_images/00109.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_366.jpg
# /kaggle/input/image-data/RSICD_images/pond_66.jpg
# /kaggle/input/image-data/RSICD_images/port_76.jpg
# /kaggle/input/image-data/RSICD_images/resort_265.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_233.jpg
# /kaggle/input/image-data/RSICD_images/forest_136.jpg
# /kaggle/input/image-data/RSICD_images/school_52.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_231.jpg
# /kaggle/input/image-data/RSICD_images/pond_357.jpg
# /kaggle/input/image-data/RSICD_images/airport_159.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_60.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_123.jpg
# /kaggle/input/image-data/RSICD_images/meadow_99.jpg
# /kaggle/input/image-data/RSICD_images/farmland_198.jpg
# /kaggle/input/image-data/RSICD_images/church_210.jpg
# /kaggle/input/image-data/RSICD_images/playground_99.jpg
# /kaggle/input/image-data/RSICD_images/park_31.jpg
# /kaggle/input/image-data/RSICD_images/airport_352.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_75.jpg
# /kaggle/input/image-data/RSICD_images/00111.jpg
# /kaggle/input/image-data/RSICD_images/park_288.jpg
# /kaggle/input/image-data/RSICD_images/mountain_133.jpg
# /kaggle/input/image-data/RSICD_images/forest_181.jpg
# /kaggle/input/image-data/RSICD_images/industrial_179.jpg
# /kaggle/input/image-data/RSICD_images/desert_118.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_225.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_328.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_123.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_326.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_136.jpg
# /kaggle/input/image-data/RSICD_images/school_124.jpg
# /kaggle/input/image-data/RSICD_images/forest_100.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_386.jpg
# /kaggle/input/image-data/RSICD_images/port_50.jpg
# /kaggle/input/image-data/RSICD_images/parking_255.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_38.jpg
# /kaggle/input/image-data/RSICD_images/port_96.jpg
# /kaggle/input/image-data/RSICD_images/airport_281.jpg
# /kaggle/input/image-data/RSICD_images/forest_174.jpg
# /kaggle/input/image-data/RSICD_images/river_28.jpg
# /kaggle/input/image-data/RSICD_images/square_255.jpg
# /kaggle/input/image-data/RSICD_images/school_101.jpg
# /kaggle/input/image-data/RSICD_images/river_200.jpg
# /kaggle/input/image-data/RSICD_images/port_290.jpg
# /kaggle/input/image-data/RSICD_images/00056.jpg
# /kaggle/input/image-data/RSICD_images/industrial_19.jpg
# /kaggle/input/image-data/RSICD_images/center_59.jpg
# /kaggle/input/image-data/RSICD_images/pond_389.jpg
# /kaggle/input/image-data/RSICD_images/playground_95.jpg
# /kaggle/input/image-data/RSICD_images/bareland_212.jpg
# /kaggle/input/image-data/RSICD_images/forest_156.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_106.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_135.jpg
# /kaggle/input/image-data/RSICD_images/bridge_253.jpg
# /kaggle/input/image-data/RSICD_images/center_13.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_204.jpg
# /kaggle/input/image-data/RSICD_images/river_277.jpg
# /kaggle/input/image-data/RSICD_images/resort_228.jpg
# /kaggle/input/image-data/RSICD_images/park_210.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_37.jpg
# /kaggle/input/image-data/RSICD_images/park_180.jpg
# /kaggle/input/image-data/RSICD_images/meadow_148.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_62.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_215.jpg
# /kaggle/input/image-data/RSICD_images/resort_175.jpg
# /kaggle/input/image-data/RSICD_images/bridge_26.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_70.jpg
# /kaggle/input/image-data/RSICD_images/resort_45.jpg
# /kaggle/input/image-data/RSICD_images/meadow_135.jpg
# /kaggle/input/image-data/RSICD_images/square_199.jpg
# /kaggle/input/image-data/RSICD_images/resort_61.jpg
# /kaggle/input/image-data/RSICD_images/airport_262.jpg
# /kaggle/input/image-data/RSICD_images/airport_49.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_168.jpg
# /kaggle/input/image-data/RSICD_images/square_100.jpg
# /kaggle/input/image-data/RSICD_images/square_58.jpg
# /kaggle/input/image-data/RSICD_images/bridge_254.jpg
# /kaggle/input/image-data/RSICD_images/square_26.jpg
# /kaggle/input/image-data/RSICD_images/river_73.jpg
# /kaggle/input/image-data/RSICD_images/park_332.jpg
# /kaggle/input/image-data/RSICD_images/00030.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_136.jpg
# /kaggle/input/image-data/RSICD_images/parking_371.jpg
# /kaggle/input/image-data/RSICD_images/00907.jpg
# /kaggle/input/image-data/RSICD_images/bareland_25.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_291.jpg
# /kaggle/input/image-data/RSICD_images/airport_198.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_81.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_188.jpg
# /kaggle/input/image-data/RSICD_images/mountain_108.jpg
# /kaggle/input/image-data/RSICD_images/school_35.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_51.jpg
# /kaggle/input/image-data/RSICD_images/river_80.jpg
# /kaggle/input/image-data/RSICD_images/meadow_145.jpg
# /kaggle/input/image-data/RSICD_images/river_384.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_90.jpg
# /kaggle/input/image-data/RSICD_images/resort_62.jpg
# /kaggle/input/image-data/RSICD_images/river_334.jpg
# /kaggle/input/image-data/RSICD_images/farmland_352.jpg
# /kaggle/input/image-data/RSICD_images/meadow_261.jpg
# /kaggle/input/image-data/RSICD_images/parking_312.jpg
# /kaggle/input/image-data/RSICD_images/bareland_96.jpg
# /kaggle/input/image-data/RSICD_images/river_171.jpg
# /kaggle/input/image-data/RSICD_images/center_19.jpg
# /kaggle/input/image-data/RSICD_images/commercial_188.jpg
# /kaggle/input/image-data/RSICD_images/commercial_329.jpg
# /kaggle/input/image-data/RSICD_images/square_17.jpg
# /kaggle/input/image-data/RSICD_images/parking_140.jpg
# /kaggle/input/image-data/RSICD_images/00680.jpg
# /kaggle/input/image-data/RSICD_images/pond_360.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_31.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_343.jpg
# /kaggle/input/image-data/RSICD_images/desert_192.jpg
# /kaggle/input/image-data/RSICD_images/church_54.jpg
# /kaggle/input/image-data/RSICD_images/square_244.jpg
# /kaggle/input/image-data/RSICD_images/bareland_233.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_47.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_247.jpg
# /kaggle/input/image-data/RSICD_images/playground_32.jpg
# /kaggle/input/image-data/RSICD_images/desert_171.jpg
# /kaggle/input/image-data/RSICD_images/park_2.jpg
# /kaggle/input/image-data/RSICD_images/park_321.jpg
# /kaggle/input/image-data/RSICD_images/park_343.jpg
# /kaggle/input/image-data/RSICD_images/park_187.jpg
# /kaggle/input/image-data/RSICD_images/church_68.jpg
# /kaggle/input/image-data/RSICD_images/00571.jpg
# /kaggle/input/image-data/RSICD_images/industrial_383.jpg
# /kaggle/input/image-data/RSICD_images/parking_298.jpg
# /kaggle/input/image-data/RSICD_images/resort_283.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_27.jpg
# /kaggle/input/image-data/RSICD_images/center_201.jpg
# /kaggle/input/image-data/RSICD_images/school_156.jpg
# /kaggle/input/image-data/RSICD_images/mountain_24.jpg
# /kaggle/input/image-data/RSICD_images/00808.jpg
# /kaggle/input/image-data/RSICD_images/airport_179.jpg
# /kaggle/input/image-data/RSICD_images/playground_200.jpg
# /kaggle/input/image-data/RSICD_images/park_41.jpg
# /kaggle/input/image-data/RSICD_images/commercial_245.jpg
# /kaggle/input/image-data/RSICD_images/meadow_218.jpg
# /kaggle/input/image-data/RSICD_images/00340.jpg
# /kaggle/input/image-data/RSICD_images/pond_83.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_91.jpg
# /kaggle/input/image-data/RSICD_images/pond_398.jpg
# /kaggle/input/image-data/RSICD_images/parking_175.jpg
# /kaggle/input/image-data/RSICD_images/park_314.jpg
# /kaggle/input/image-data/RSICD_images/desert_10.jpg
# /kaggle/input/image-data/RSICD_images/00074.jpg
# /kaggle/input/image-data/RSICD_images/beach_237.jpg
# /kaggle/input/image-data/RSICD_images/00009.jpg
# /kaggle/input/image-data/RSICD_images/commercial_155.jpg
# /kaggle/input/image-data/RSICD_images/00530.jpg
# /kaggle/input/image-data/RSICD_images/stadium_261.jpg
# /kaggle/input/image-data/RSICD_images/port_336.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_169.jpg
# /kaggle/input/image-data/RSICD_images/00361.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_78.jpg
# /kaggle/input/image-data/RSICD_images/pond_326.jpg
# /kaggle/input/image-data/RSICD_images/church_116.jpg
# /kaggle/input/image-data/RSICD_images/parking_23.jpg
# /kaggle/input/image-data/RSICD_images/center_190.jpg
# /kaggle/input/image-data/RSICD_images/bridge_95.jpg
# /kaggle/input/image-data/RSICD_images/forest_228.jpg
# /kaggle/input/image-data/RSICD_images/pond_322.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_274.jpg
# /kaggle/input/image-data/RSICD_images/resort_22.jpg
# /kaggle/input/image-data/RSICD_images/playground_348.jpg
# /kaggle/input/image-data/RSICD_images/bridge_4.jpg
# /kaggle/input/image-data/RSICD_images/commercial_41.jpg
# /kaggle/input/image-data/RSICD_images/playground_66.jpg
# /kaggle/input/image-data/RSICD_images/center_221.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_37.jpg
# /kaggle/input/image-data/RSICD_images/school_143.jpg
# /kaggle/input/image-data/RSICD_images/pond_367.jpg
# /kaggle/input/image-data/RSICD_images/resort_206.jpg
# /kaggle/input/image-data/RSICD_images/center_88.jpg
# /kaggle/input/image-data/RSICD_images/stadium_80.jpg
# /kaggle/input/image-data/RSICD_images/farmland_149.jpg
# /kaggle/input/image-data/RSICD_images/playground_161.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_125.jpg
# /kaggle/input/image-data/RSICD_images/00308.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_222.jpg
# /kaggle/input/image-data/RSICD_images/port_60.jpg
# /kaggle/input/image-data/RSICD_images/bareland_95.jpg
# /kaggle/input/image-data/RSICD_images/industrial_14.jpg
# /kaggle/input/image-data/RSICD_images/meadow_108.jpg
# /kaggle/input/image-data/RSICD_images/airport_217.jpg
# /kaggle/input/image-data/RSICD_images/park_118.jpg
# /kaggle/input/image-data/RSICD_images/church_85.jpg
# /kaggle/input/image-data/RSICD_images/port_257.jpg
# /kaggle/input/image-data/RSICD_images/playground_314.jpg
# /kaggle/input/image-data/RSICD_images/bareland_24.jpg
# /kaggle/input/image-data/RSICD_images/airport_282.jpg
# /kaggle/input/image-data/RSICD_images/pond_51.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_133.jpg
# /kaggle/input/image-data/RSICD_images/farmland_104.jpg
# /kaggle/input/image-data/RSICD_images/parking_385.jpg
# /kaggle/input/image-data/RSICD_images/river_388.jpg
# /kaggle/input/image-data/RSICD_images/port_317.jpg
# /kaggle/input/image-data/RSICD_images/00580.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_158.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_92.jpg
# /kaggle/input/image-data/RSICD_images/commercial_194.jpg
# /kaggle/input/image-data/RSICD_images/farmland_217.jpg
# /kaggle/input/image-data/RSICD_images/00439.jpg
# /kaggle/input/image-data/RSICD_images/playground_89.jpg
# /kaggle/input/image-data/RSICD_images/commercial_15.jpg
# /kaggle/input/image-data/RSICD_images/beach_207.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_94.jpg
# /kaggle/input/image-data/RSICD_images/port_206.jpg
# /kaggle/input/image-data/RSICD_images/beach_224.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_245.jpg
# /kaggle/input/image-data/RSICD_images/desert_289.jpg
# /kaggle/input/image-data/RSICD_images/bridge_187.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_107.jpg
# /kaggle/input/image-data/RSICD_images/00161.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_182.jpg
# /kaggle/input/image-data/RSICD_images/playground_169.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_8.jpg
# /kaggle/input/image-data/RSICD_images/commercial_98.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_130.jpg
# /kaggle/input/image-data/RSICD_images/desert_178.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_82.jpg
# /kaggle/input/image-data/RSICD_images/center_125.jpg
# /kaggle/input/image-data/RSICD_images/meadow_222.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_174.jpg
# /kaggle/input/image-data/RSICD_images/industrial_198.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_33.jpg
# /kaggle/input/image-data/RSICD_images/00377.jpg
# /kaggle/input/image-data/RSICD_images/stadium_288.jpg
# /kaggle/input/image-data/RSICD_images/pond_295.jpg
# /kaggle/input/image-data/RSICD_images/parking_103.jpg
# /kaggle/input/image-data/RSICD_images/bareland_61.jpg
# /kaggle/input/image-data/RSICD_images/center_215.jpg
# /kaggle/input/image-data/RSICD_images/industrial_315.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_121.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_146.jpg
# /kaggle/input/image-data/RSICD_images/desert_17.jpg
# /kaggle/input/image-data/RSICD_images/airport_20.jpg
# /kaggle/input/image-data/RSICD_images/square_139.jpg
# /kaggle/input/image-data/RSICD_images/commercial_146.jpg
# /kaggle/input/image-data/RSICD_images/00802.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_137.jpg
# /kaggle/input/image-data/RSICD_images/square_24.jpg
# /kaggle/input/image-data/RSICD_images/bridge_80.jpg
# /kaggle/input/image-data/RSICD_images/farmland_154.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_62.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_42.jpg
# /kaggle/input/image-data/RSICD_images/pond_36.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_72.jpg
# /kaggle/input/image-data/RSICD_images/parking_384.jpg
# /kaggle/input/image-data/RSICD_images/desert_33.jpg
# /kaggle/input/image-data/RSICD_images/meadow_186.jpg
# /kaggle/input/image-data/RSICD_images/pond_283.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_220.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_123.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_408.jpg
# /kaggle/input/image-data/RSICD_images/pond_161.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_288.jpg
# /kaggle/input/image-data/RSICD_images/commercial_304.jpg
# /kaggle/input/image-data/RSICD_images/pond_60.jpg
# /kaggle/input/image-data/RSICD_images/beach_312.jpg
# /kaggle/input/image-data/RSICD_images/river_51.jpg
# /kaggle/input/image-data/RSICD_images/playground_126.jpg
# /kaggle/input/image-data/RSICD_images/square_218.jpg
# /kaggle/input/image-data/RSICD_images/port_45.jpg
# /kaggle/input/image-data/RSICD_images/river_55.jpg
# /kaggle/input/image-data/RSICD_images/airport_80.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_377.jpg
# /kaggle/input/image-data/RSICD_images/desert_254.jpg
# /kaggle/input/image-data/RSICD_images/school_232.jpg
# /kaggle/input/image-data/RSICD_images/parking_328.jpg
# /kaggle/input/image-data/RSICD_images/port_154.jpg
# /kaggle/input/image-data/RSICD_images/parking_244.jpg
# /kaggle/input/image-data/RSICD_images/park_236.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_50.jpg
# /kaggle/input/image-data/RSICD_images/square_324.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_362.jpg
# /kaggle/input/image-data/RSICD_images/port_159.jpg
# /kaggle/input/image-data/RSICD_images/00215.jpg
# /kaggle/input/image-data/RSICD_images/stadium_279.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_46.jpg
# /kaggle/input/image-data/RSICD_images/school_3.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_287.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_290.jpg
# /kaggle/input/image-data/RSICD_images/00116.jpg
# /kaggle/input/image-data/RSICD_images/commercial_120.jpg
# /kaggle/input/image-data/RSICD_images/farmland_307.jpg
# /kaggle/input/image-data/RSICD_images/beach_362.jpg
# /kaggle/input/image-data/RSICD_images/bareland_248.jpg
# /kaggle/input/image-data/RSICD_images/airport_209.jpg
# /kaggle/input/image-data/RSICD_images/square_292.jpg
# /kaggle/input/image-data/RSICD_images/bridge_129.jpg
# /kaggle/input/image-data/RSICD_images/stadium_181.jpg
# /kaggle/input/image-data/RSICD_images/church_104.jpg
# /kaggle/input/image-data/RSICD_images/parking_86.jpg
# /kaggle/input/image-data/RSICD_images/00681.jpg
# /kaggle/input/image-data/RSICD_images/forest_118.jpg
# /kaggle/input/image-data/RSICD_images/pond_14.jpg
# /kaggle/input/image-data/RSICD_images/bareland_72.jpg
# /kaggle/input/image-data/RSICD_images/airport_7.jpg
# /kaggle/input/image-data/RSICD_images/parking_234.jpg
# /kaggle/input/image-data/RSICD_images/park_11.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_242.jpg
# /kaggle/input/image-data/RSICD_images/airport_357.jpg
# /kaggle/input/image-data/RSICD_images/pond_116.jpg
# /kaggle/input/image-data/RSICD_images/airport_107.jpg
# /kaggle/input/image-data/RSICD_images/mountain_170.jpg
# /kaggle/input/image-data/RSICD_images/farmland_245.jpg
# /kaggle/input/image-data/RSICD_images/commercial_317.jpg
# /kaggle/input/image-data/RSICD_images/desert_166.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_142.jpg
# /kaggle/input/image-data/RSICD_images/00081.jpg
# /kaggle/input/image-data/RSICD_images/bridge_305.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_230.jpg
# /kaggle/input/image-data/RSICD_images/00280.jpg
# /kaggle/input/image-data/RSICD_images/airport_125.jpg
# /kaggle/input/image-data/RSICD_images/church_38.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_278.jpg
# /kaggle/input/image-data/RSICD_images/meadow_13.jpg
# /kaggle/input/image-data/RSICD_images/stadium_98.jpg
# /kaggle/input/image-data/RSICD_images/airport_252.jpg
# /kaggle/input/image-data/RSICD_images/church_212.jpg
# /kaggle/input/image-data/RSICD_images/stadium_24.jpg
# /kaggle/input/image-data/RSICD_images/river_408.jpg
# /kaggle/input/image-data/RSICD_images/00428.jpg
# /kaggle/input/image-data/RSICD_images/industrial_96.jpg
# /kaggle/input/image-data/RSICD_images/center_130.jpg
# /kaggle/input/image-data/RSICD_images/river_310.jpg
# /kaggle/input/image-data/RSICD_images/farmland_132.jpg
# /kaggle/input/image-data/RSICD_images/industrial_39.jpg
# /kaggle/input/image-data/RSICD_images/stadium_228.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_73.jpg
# /kaggle/input/image-data/RSICD_images/bridge_302.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_313.jpg
# /kaggle/input/image-data/RSICD_images/parking_379.jpg
# /kaggle/input/image-data/RSICD_images/farmland_59.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_61.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_80.jpg
# /kaggle/input/image-data/RSICD_images/park_26.jpg
# /kaggle/input/image-data/RSICD_images/mountain_53.jpg
# /kaggle/input/image-data/RSICD_images/00468.jpg
# /kaggle/input/image-data/RSICD_images/school_73.jpg
# /kaggle/input/image-data/RSICD_images/00324.jpg
# /kaggle/input/image-data/RSICD_images/parking_143.jpg
# /kaggle/input/image-data/RSICD_images/pond_202.jpg
# /kaggle/input/image-data/RSICD_images/bareland_234.jpg
# /kaggle/input/image-data/RSICD_images/river_353.jpg
# /kaggle/input/image-data/RSICD_images/pond_243.jpg
# /kaggle/input/image-data/RSICD_images/park_50.jpg
# /kaggle/input/image-data/RSICD_images/airport_334.jpg
# /kaggle/input/image-data/RSICD_images/park_164.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_177.jpg
# /kaggle/input/image-data/RSICD_images/church_231.jpg
# /kaggle/input/image-data/RSICD_images/beach_330.jpg
# /kaggle/input/image-data/RSICD_images/industrial_188.jpg
# /kaggle/input/image-data/RSICD_images/parking_225.jpg
# /kaggle/input/image-data/RSICD_images/industrial_106.jpg
# /kaggle/input/image-data/RSICD_images/parking_61.jpg
# /kaggle/input/image-data/RSICD_images/park_221.jpg
# /kaggle/input/image-data/RSICD_images/commercial_122.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_45.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_56.jpg
# /kaggle/input/image-data/RSICD_images/desert_214.jpg
# /kaggle/input/image-data/RSICD_images/parking_217.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_182.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_77.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_271.jpg
# /kaggle/input/image-data/RSICD_images/industrial_176.jpg
# /kaggle/input/image-data/RSICD_images/00694.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_63.jpg
# /kaggle/input/image-data/RSICD_images/commercial_232.jpg
# /kaggle/input/image-data/RSICD_images/square_242.jpg
# /kaggle/input/image-data/RSICD_images/desert_247.jpg
# /kaggle/input/image-data/RSICD_images/bareland_107.jpg
# /kaggle/input/image-data/RSICD_images/00596.jpg
# /kaggle/input/image-data/RSICD_images/industrial_292.jpg
# /kaggle/input/image-data/RSICD_images/port_38.jpg
# /kaggle/input/image-data/RSICD_images/00787.jpg
# /kaggle/input/image-data/RSICD_images/beach_368.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_280.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_257.jpg
# /kaggle/input/image-data/RSICD_images/pond_310.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_211.jpg
# /kaggle/input/image-data/RSICD_images/commercial_114.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_306.jpg
# /kaggle/input/image-data/RSICD_images/square_248.jpg
# /kaggle/input/image-data/RSICD_images/square_197.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_46.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_146.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_227.jpg
# /kaggle/input/image-data/RSICD_images/commercial_112.jpg
# /kaggle/input/image-data/RSICD_images/00879.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_332.jpg
# /kaggle/input/image-data/RSICD_images/park_174.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_260.jpg
# /kaggle/input/image-data/RSICD_images/airport_33.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_109.jpg
# /kaggle/input/image-data/RSICD_images/00316.jpg
# /kaggle/input/image-data/RSICD_images/square_111.jpg
# /kaggle/input/image-data/RSICD_images/00269.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_201.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_247.jpg
# /kaggle/input/image-data/RSICD_images/00364.jpg
# /kaggle/input/image-data/RSICD_images/commercial_158.jpg
# /kaggle/input/image-data/RSICD_images/port_252.jpg
# /kaggle/input/image-data/RSICD_images/00299.jpg
# /kaggle/input/image-data/RSICD_images/stadium_16.jpg
# /kaggle/input/image-data/RSICD_images/industrial_141.jpg
# /kaggle/input/image-data/RSICD_images/beach_89.jpg
# /kaggle/input/image-data/RSICD_images/bridge_299.jpg
# /kaggle/input/image-data/RSICD_images/park_318.jpg
# /kaggle/input/image-data/RSICD_images/center_218.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_26.jpg
# /kaggle/input/image-data/RSICD_images/bridge_52.jpg
# /kaggle/input/image-data/RSICD_images/bridge_144.jpg
# /kaggle/input/image-data/RSICD_images/00754.jpg
# /kaggle/input/image-data/RSICD_images/mountain_71.jpg
# /kaggle/input/image-data/RSICD_images/parking_311.jpg
# /kaggle/input/image-data/RSICD_images/farmland_112.jpg
# /kaggle/input/image-data/RSICD_images/church_128.jpg
# /kaggle/input/image-data/RSICD_images/commercial_290.jpg
# /kaggle/input/image-data/RSICD_images/farmland_165.jpg
# /kaggle/input/image-data/RSICD_images/pond_314.jpg
# /kaggle/input/image-data/RSICD_images/00872.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_389.jpg
# /kaggle/input/image-data/RSICD_images/port_249.jpg
# /kaggle/input/image-data/RSICD_images/desert_90.jpg
# /kaggle/input/image-data/RSICD_images/church_141.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_349.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_289.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_197.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_3.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_250.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_171.jpg
# /kaggle/input/image-data/RSICD_images/port_133.jpg
# /kaggle/input/image-data/RSICD_images/center_214.jpg
# /kaggle/input/image-data/RSICD_images/industrial_74.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_118.jpg
# /kaggle/input/image-data/RSICD_images/commercial_248.jpg
# /kaggle/input/image-data/RSICD_images/beach_156.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_139.jpg
# /kaggle/input/image-data/RSICD_images/stadium_75.jpg
# /kaggle/input/image-data/RSICD_images/stadium_94.jpg
# /kaggle/input/image-data/RSICD_images/mountain_164.jpg
# /kaggle/input/image-data/RSICD_images/river_93.jpg
# /kaggle/input/image-data/RSICD_images/00743.jpg
# /kaggle/input/image-data/RSICD_images/meadow_56.jpg
# /kaggle/input/image-data/RSICD_images/bridge_150.jpg
# /kaggle/input/image-data/RSICD_images/school_150.jpg
# /kaggle/input/image-data/RSICD_images/meadow_98.jpg
# /kaggle/input/image-data/RSICD_images/resort_40.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_366.jpg
# /kaggle/input/image-data/RSICD_images/bareland_177.jpg
# /kaggle/input/image-data/RSICD_images/pond_219.jpg
# /kaggle/input/image-data/RSICD_images/bareland_268.jpg
# /kaggle/input/image-data/RSICD_images/commercial_273.jpg
# /kaggle/input/image-data/RSICD_images/bridge_86.jpg
# /kaggle/input/image-data/RSICD_images/pond_168.jpg
# /kaggle/input/image-data/RSICD_images/stadium_10.jpg
# /kaggle/input/image-data/RSICD_images/stadium_71.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_84.jpg
# /kaggle/input/image-data/RSICD_images/school_299.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_156.jpg
# /kaggle/input/image-data/RSICD_images/industrial_35.jpg
# /kaggle/input/image-data/RSICD_images/bridge_60.jpg
# /kaggle/input/image-data/RSICD_images/industrial_246.jpg
# /kaggle/input/image-data/RSICD_images/00560.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_74.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_64.jpg
# /kaggle/input/image-data/RSICD_images/farmland_24.jpg
# /kaggle/input/image-data/RSICD_images/center_40.jpg
# /kaggle/input/image-data/RSICD_images/square_228.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_304.jpg
# /kaggle/input/image-data/RSICD_images/church_235.jpg
# /kaggle/input/image-data/RSICD_images/beach_24.jpg
# /kaggle/input/image-data/RSICD_images/farmland_305.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_102.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_256.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_299.jpg
# /kaggle/input/image-data/RSICD_images/00386.jpg
# /kaggle/input/image-data/RSICD_images/airport_158.jpg
# /kaggle/input/image-data/RSICD_images/square_13.jpg
# /kaggle/input/image-data/RSICD_images/forest_180.jpg
# /kaggle/input/image-data/RSICD_images/00498.jpg
# /kaggle/input/image-data/RSICD_images/forest_18.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_371.jpg
# /kaggle/input/image-data/RSICD_images/airport_58.jpg
# /kaggle/input/image-data/RSICD_images/stadium_107.jpg
# /kaggle/input/image-data/RSICD_images/desert_116.jpg
# /kaggle/input/image-data/RSICD_images/00581.jpg
# /kaggle/input/image-data/RSICD_images/school_141.jpg
# /kaggle/input/image-data/RSICD_images/church_24.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_265.jpg
# /kaggle/input/image-data/RSICD_images/airport_250.jpg
# /kaggle/input/image-data/RSICD_images/industrial_172.jpg
# /kaggle/input/image-data/RSICD_images/port_123.jpg
# /kaggle/input/image-data/RSICD_images/bridge_114.jpg
# /kaggle/input/image-data/RSICD_images/commercial_318.jpg
# /kaggle/input/image-data/RSICD_images/stadium_198.jpg
# /kaggle/input/image-data/RSICD_images/park_123.jpg
# /kaggle/input/image-data/RSICD_images/desert_22.jpg
# /kaggle/input/image-data/RSICD_images/meadow_45.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_18.jpg
# /kaggle/input/image-data/RSICD_images/parking_203.jpg
# /kaggle/input/image-data/RSICD_images/bareland_5.jpg
# /kaggle/input/image-data/RSICD_images/parking_134.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_178.jpg
# /kaggle/input/image-data/RSICD_images/industrial_256.jpg
# /kaggle/input/image-data/RSICD_images/stadium_230.jpg
# /kaggle/input/image-data/RSICD_images/river_347.jpg
# /kaggle/input/image-data/RSICD_images/bridge_298.jpg
# /kaggle/input/image-data/RSICD_images/farmland_349.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_12.jpg
# /kaggle/input/image-data/RSICD_images/park_306.jpg
# /kaggle/input/image-data/RSICD_images/center_114.jpg
# /kaggle/input/image-data/RSICD_images/airport_237.jpg
# /kaggle/input/image-data/RSICD_images/stadium_112.jpg
# /kaggle/input/image-data/RSICD_images/mountain_286.jpg
# /kaggle/input/image-data/RSICD_images/bareland_236.jpg
# /kaggle/input/image-data/RSICD_images/river_1.jpg
# /kaggle/input/image-data/RSICD_images/center_73.jpg
# /kaggle/input/image-data/RSICD_images/farmland_162.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_11.jpg
# /kaggle/input/image-data/RSICD_images/00629.jpg
# /kaggle/input/image-data/RSICD_images/mountain_227.jpg
# /kaggle/input/image-data/RSICD_images/school_112.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_236.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_230.jpg
# /kaggle/input/image-data/RSICD_images/pond_257.jpg
# /kaggle/input/image-data/RSICD_images/00795.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_135.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_379.jpg
# /kaggle/input/image-data/RSICD_images/desert_249.jpg
# /kaggle/input/image-data/RSICD_images/church_5.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_192.jpg
# /kaggle/input/image-data/RSICD_images/mountain_264.jpg
# /kaggle/input/image-data/RSICD_images/pond_382.jpg
# /kaggle/input/image-data/RSICD_images/square_262.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_67.jpg
# /kaggle/input/image-data/RSICD_images/playground_208.jpg
# /kaggle/input/image-data/RSICD_images/beach_54.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_149.jpg
# /kaggle/input/image-data/RSICD_images/resort_212.jpg
# /kaggle/input/image-data/RSICD_images/farmland_110.jpg
# /kaggle/input/image-data/RSICD_images/desert_298.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_209.jpg
# /kaggle/input/image-data/RSICD_images/farmland_60.jpg
# /kaggle/input/image-data/RSICD_images/00784.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_287.jpg
# /kaggle/input/image-data/RSICD_images/farmland_314.jpg
# /kaggle/input/image-data/RSICD_images/stadium_17.jpg
# /kaggle/input/image-data/RSICD_images/beach_270.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_219.jpg
# /kaggle/input/image-data/RSICD_images/meadow_10.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_238.jpg
# /kaggle/input/image-data/RSICD_images/00785.jpg
# /kaggle/input/image-data/RSICD_images/bridge_32.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_30.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_98.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_211.jpg
# /kaggle/input/image-data/RSICD_images/commercial_139.jpg
# /kaggle/input/image-data/RSICD_images/industrial_220.jpg
# /kaggle/input/image-data/RSICD_images/stadium_240.jpg
# /kaggle/input/image-data/RSICD_images/playground_283.jpg
# /kaggle/input/image-data/RSICD_images/pond_188.jpg
# /kaggle/input/image-data/RSICD_images/pond_91.jpg
# /kaggle/input/image-data/RSICD_images/resort_240.jpg
# /kaggle/input/image-data/RSICD_images/school_243.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_99.jpg
# /kaggle/input/image-data/RSICD_images/port_258.jpg
# /kaggle/input/image-data/RSICD_images/00516.jpg
# /kaggle/input/image-data/RSICD_images/meadow_155.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_297.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_216.jpg
# /kaggle/input/image-data/RSICD_images/church_35.jpg
# /kaggle/input/image-data/RSICD_images/square_69.jpg
# /kaggle/input/image-data/RSICD_images/beach_170.jpg
# /kaggle/input/image-data/RSICD_images/commercial_230.jpg
# /kaggle/input/image-data/RSICD_images/farmland_109.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_289.jpg
# /kaggle/input/image-data/RSICD_images/mountain_173.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_181.jpg
# /kaggle/input/image-data/RSICD_images/playground_305.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_234.jpg
# /kaggle/input/image-data/RSICD_images/school_111.jpg
# /kaggle/input/image-data/RSICD_images/airport_306.jpg
# /kaggle/input/image-data/RSICD_images/industrial_15.jpg
# /kaggle/input/image-data/RSICD_images/beach_21.jpg
# /kaggle/input/image-data/RSICD_images/center_136.jpg
# /kaggle/input/image-data/RSICD_images/industrial_227.jpg
# /kaggle/input/image-data/RSICD_images/park_227.jpg
# /kaggle/input/image-data/RSICD_images/desert_287.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_255.jpg
# /kaggle/input/image-data/RSICD_images/bridge_313.jpg
# /kaggle/input/image-data/RSICD_images/desert_93.jpg
# /kaggle/input/image-data/RSICD_images/parking_58.jpg
# /kaggle/input/image-data/RSICD_images/bareland_114.jpg
# /kaggle/input/image-data/RSICD_images/resort_290.jpg
# /kaggle/input/image-data/RSICD_images/00363.jpg
# /kaggle/input/image-data/RSICD_images/church_108.jpg
# /kaggle/input/image-data/RSICD_images/pond_399.jpg
# /kaggle/input/image-data/RSICD_images/farmland_312.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_300.jpg
# /kaggle/input/image-data/RSICD_images/commercial_175.jpg
# /kaggle/input/image-data/RSICD_images/parking_63.jpg
# /kaggle/input/image-data/RSICD_images/bridge_311.jpg
# /kaggle/input/image-data/RSICD_images/parking_158.jpg
# /kaggle/input/image-data/RSICD_images/parking_30.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_113.jpg
# /kaggle/input/image-data/RSICD_images/beach_177.jpg
# /kaggle/input/image-data/RSICD_images/industrial_303.jpg
# /kaggle/input/image-data/RSICD_images/school_114.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_43.jpg
# /kaggle/input/image-data/RSICD_images/beach_163.jpg
# /kaggle/input/image-data/RSICD_images/square_290.jpg
# /kaggle/input/image-data/RSICD_images/park_66.jpg
# /kaggle/input/image-data/RSICD_images/industrial_377.jpg
# /kaggle/input/image-data/RSICD_images/bridge_242.jpg
# /kaggle/input/image-data/RSICD_images/river_57.jpg
# /kaggle/input/image-data/RSICD_images/river_281.jpg
# /kaggle/input/image-data/RSICD_images/mountain_128.jpg
# /kaggle/input/image-data/RSICD_images/airport_312.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_6.jpg
# /kaggle/input/image-data/RSICD_images/square_46.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_93.jpg
# /kaggle/input/image-data/RSICD_images/desert_273.jpg
# /kaggle/input/image-data/RSICD_images/center_212.jpg
# /kaggle/input/image-data/RSICD_images/square_271.jpg
# /kaggle/input/image-data/RSICD_images/bridge_280.jpg
# /kaggle/input/image-data/RSICD_images/00413.jpg
# /kaggle/input/image-data/RSICD_images/desert_96.jpg
# /kaggle/input/image-data/RSICD_images/commercial_343.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_172.jpg
# /kaggle/input/image-data/RSICD_images/beach_195.jpg
# /kaggle/input/image-data/RSICD_images/industrial_345.jpg
# /kaggle/input/image-data/RSICD_images/resort_174.jpg
# /kaggle/input/image-data/RSICD_images/river_15.jpg
# /kaggle/input/image-data/RSICD_images/pond_140.jpg
# /kaggle/input/image-data/RSICD_images/square_289.jpg
# /kaggle/input/image-data/RSICD_images/school_296.jpg
# /kaggle/input/image-data/RSICD_images/stadium_36.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_407.jpg
# /kaggle/input/image-data/RSICD_images/desert_98.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_299.jpg
# /kaggle/input/image-data/RSICD_images/forest_60.jpg
# /kaggle/input/image-data/RSICD_images/pond_313.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_7.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_133.jpg
# /kaggle/input/image-data/RSICD_images/desert_184.jpg
# /kaggle/input/image-data/RSICD_images/port_223.jpg
# /kaggle/input/image-data/RSICD_images/port_242.jpg
# /kaggle/input/image-data/RSICD_images/00893.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_370.jpg
# /kaggle/input/image-data/RSICD_images/industrial_87.jpg
# /kaggle/input/image-data/RSICD_images/resort_27.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_102.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_143.jpg
# /kaggle/input/image-data/RSICD_images/parking_192.jpg
# /kaggle/input/image-data/RSICD_images/beach_284.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_133.jpg
# /kaggle/input/image-data/RSICD_images/industrial_212.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_55.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_223.jpg
# /kaggle/input/image-data/RSICD_images/bridge_160.jpg
# /kaggle/input/image-data/RSICD_images/bareland_297.jpg
# /kaggle/input/image-data/RSICD_images/square_43.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_2.jpg
# /kaggle/input/image-data/RSICD_images/00237.jpg
# /kaggle/input/image-data/RSICD_images/bareland_100.jpg
# /kaggle/input/image-data/RSICD_images/airport_309.jpg
# /kaggle/input/image-data/RSICD_images/00381.jpg
# /kaggle/input/image-data/RSICD_images/church_52.jpg
# /kaggle/input/image-data/RSICD_images/beach_178.jpg
# /kaggle/input/image-data/RSICD_images/school_14.jpg
# /kaggle/input/image-data/RSICD_images/airport_96.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_249.jpg
# /kaggle/input/image-data/RSICD_images/airport_305.jpg
# /kaggle/input/image-data/RSICD_images/bareland_257.jpg
# /kaggle/input/image-data/RSICD_images/forest_231.jpg
# /kaggle/input/image-data/RSICD_images/farmland_80.jpg
# /kaggle/input/image-data/RSICD_images/river_387.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_370.jpg
# /kaggle/input/image-data/RSICD_images/church_26.jpg
# /kaggle/input/image-data/RSICD_images/beach_297.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_166.jpg
# /kaggle/input/image-data/RSICD_images/00617.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_48.jpg
# /kaggle/input/image-data/RSICD_images/school_217.jpg
# /kaggle/input/image-data/RSICD_images/bridge_190.jpg
# /kaggle/input/image-data/RSICD_images/square_202.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_56.jpg
# /kaggle/input/image-data/RSICD_images/commercial_13.jpg
# /kaggle/input/image-data/RSICD_images/park_94.jpg
# /kaggle/input/image-data/RSICD_images/pond_296.jpg
# /kaggle/input/image-data/RSICD_images/meadow_109.jpg
# /kaggle/input/image-data/RSICD_images/beach_74.jpg
# /kaggle/input/image-data/RSICD_images/beach_111.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_176.jpg
# /kaggle/input/image-data/RSICD_images/meadow_235.jpg
# /kaggle/input/image-data/RSICD_images/playground_124.jpg
# /kaggle/input/image-data/RSICD_images/forest_1.jpg
# /kaggle/input/image-data/RSICD_images/forest_57.jpg
# /kaggle/input/image-data/RSICD_images/resort_69.jpg
# /kaggle/input/image-data/RSICD_images/resort_59.jpg
# /kaggle/input/image-data/RSICD_images/farmland_186.jpg
# /kaggle/input/image-data/RSICD_images/park_100.jpg
# /kaggle/input/image-data/RSICD_images/industrial_353.jpg
# /kaggle/input/image-data/RSICD_images/stadium_121.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_239.jpg
# /kaggle/input/image-data/RSICD_images/bridge_77.jpg
# /kaggle/input/image-data/RSICD_images/stadium_120.jpg
# /kaggle/input/image-data/RSICD_images/stadium_290.jpg
# /kaggle/input/image-data/RSICD_images/farmland_130.jpg
# /kaggle/input/image-data/RSICD_images/commercial_72.jpg
# /kaggle/input/image-data/RSICD_images/square_222.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_380.jpg
# /kaggle/input/image-data/RSICD_images/00359.jpg
# /kaggle/input/image-data/RSICD_images/mountain_22.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_110.jpg
# /kaggle/input/image-data/RSICD_images/desert_130.jpg
# /kaggle/input/image-data/RSICD_images/bareland_117.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_408.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_157.jpg
# /kaggle/input/image-data/RSICD_images/parking_301.jpg
# /kaggle/input/image-data/RSICD_images/desert_140.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_100.jpg
# /kaggle/input/image-data/RSICD_images/bridge_286.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_222.jpg
# /kaggle/input/image-data/RSICD_images/center_165.jpg
# /kaggle/input/image-data/RSICD_images/farmland_326.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_40.jpg
# /kaggle/input/image-data/RSICD_images/bareland_53.jpg
# /kaggle/input/image-data/RSICD_images/forest_167.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_196.jpg
# ...
# /kaggle/input/image-data/RSICD_images/park_267.jpg
# /kaggle/input/image-data/RSICD_images/farmland_103.jpg
# /kaggle/input/image-data/RSICD_images/commercial_308.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_142.jpg
# /kaggle/input/image-data/RSICD_images/commercial_164.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_42.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_176.jpg
# /kaggle/input/image-data/RSICD_images/center_28.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_290.jpg
# /kaggle/input/image-data/RSICD_images/church_169.jpg
# /kaggle/input/image-data/RSICD_images/port_272.jpg
# /kaggle/input/image-data/RSICD_images/pond_401.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_188.jpg
# /kaggle/input/image-data/RSICD_images/meadow_252.jpg
# /kaggle/input/image-data/RSICD_images/00232.jpg
# /kaggle/input/image-data/RSICD_images/commercial_35.jpg
# /kaggle/input/image-data/RSICD_images/school_166.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_106.jpg
# /kaggle/input/image-data/RSICD_images/industrial_146.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_58.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_57.jpg
# /kaggle/input/image-data/RSICD_images/parking_222.jpg
# /kaggle/input/image-data/RSICD_images/stadium_21.jpg
# /kaggle/input/image-data/RSICD_images/00616.jpg
# /kaggle/input/image-data/RSICD_images/stadium_179.jpg
# /kaggle/input/image-data/RSICD_images/center_123.jpg
# /kaggle/input/image-data/RSICD_images/commercial_206.jpg
# /kaggle/input/image-data/RSICD_images/playground_143.jpg
# /kaggle/input/image-data/RSICD_images/meadow_81.jpg
# /kaggle/input/image-data/RSICD_images/port_275.jpg
# /kaggle/input/image-data/RSICD_images/church_37.jpg
# /kaggle/input/image-data/RSICD_images/park_25.jpg
# /kaggle/input/image-data/RSICD_images/park_109.jpg
# /kaggle/input/image-data/RSICD_images/square_64.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_172.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_242.jpg
# /kaggle/input/image-data/RSICD_images/bareland_80.jpg
# /kaggle/input/image-data/RSICD_images/airport_117.jpg
# /kaggle/input/image-data/RSICD_images/stadium_14.jpg
# /kaggle/input/image-data/RSICD_images/stadium_114.jpg
# /kaggle/input/image-data/RSICD_images/farmland_10.jpg
# /kaggle/input/image-data/RSICD_images/square_181.jpg
# /kaggle/input/image-data/RSICD_images/park_273.jpg
# /kaggle/input/image-data/RSICD_images/industrial_322.jpg
# /kaggle/input/image-data/RSICD_images/industrial_162.jpg
# /kaggle/input/image-data/RSICD_images/farmland_344.jpg
# /kaggle/input/image-data/RSICD_images/beach_181.jpg
# /kaggle/input/image-data/RSICD_images/center_133.jpg
# /kaggle/input/image-data/RSICD_images/port_276.jpg
# /kaggle/input/image-data/RSICD_images/port_170.jpg
# /kaggle/input/image-data/RSICD_images/port_325.jpg
# /kaggle/input/image-data/RSICD_images/farmland_174.jpg
# /kaggle/input/image-data/RSICD_images/stadium_35.jpg
# /kaggle/input/image-data/RSICD_images/port_46.jpg
# /kaggle/input/image-data/RSICD_images/00606.jpg
# /kaggle/input/image-data/RSICD_images/parking_118.jpg
# /kaggle/input/image-data/RSICD_images/resort_224.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_177.jpg
# /kaggle/input/image-data/RSICD_images/port_227.jpg
# /kaggle/input/image-data/RSICD_images/desert_21.jpg
# /kaggle/input/image-data/RSICD_images/commercial_147.jpg
# /kaggle/input/image-data/RSICD_images/bridge_189.jpg
# /kaggle/input/image-data/RSICD_images/resort_257.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_137.jpg
# /kaggle/input/image-data/RSICD_images/desert_106.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_165.jpg
# /kaggle/input/image-data/RSICD_images/pond_335.jpg
# /kaggle/input/image-data/RSICD_images/church_103.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_178.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_278.jpg
# /kaggle/input/image-data/RSICD_images/parking_113.jpg
# /kaggle/input/image-data/RSICD_images/00845.jpg
# /kaggle/input/image-data/RSICD_images/desert_99.jpg
# /kaggle/input/image-data/RSICD_images/school_270.jpg
# /kaggle/input/image-data/RSICD_images/center_65.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_130.jpg
# /kaggle/input/image-data/RSICD_images/playground_287.jpg
# /kaggle/input/image-data/RSICD_images/port_178.jpg
# /kaggle/input/image-data/RSICD_images/port_158.jpg
# /kaggle/input/image-data/RSICD_images/river_253.jpg
# /kaggle/input/image-data/RSICD_images/desert_6.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_113.jpg
# /kaggle/input/image-data/RSICD_images/forest_65.jpg
# /kaggle/input/image-data/RSICD_images/church_20.jpg
# /kaggle/input/image-data/RSICD_images/mountain_86.jpg
# /kaggle/input/image-data/RSICD_images/playground_150.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_120.jpg
# /kaggle/input/image-data/RSICD_images/center_178.jpg
# /kaggle/input/image-data/RSICD_images/meadow_24.jpg
# /kaggle/input/image-data/RSICD_images/00590.jpg
# /kaggle/input/image-data/RSICD_images/port_341.jpg
# /kaggle/input/image-data/RSICD_images/mountain_9.jpg
# /kaggle/input/image-data/RSICD_images/pond_179.jpg
# /kaggle/input/image-data/RSICD_images/airport_85.jpg
# /kaggle/input/image-data/RSICD_images/meadow_73.jpg
# /kaggle/input/image-data/RSICD_images/park_65.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_204.jpg
# /kaggle/input/image-data/RSICD_images/desert_72.jpg
# /kaggle/input/image-data/RSICD_images/park_69.jpg
# /kaggle/input/image-data/RSICD_images/pond_275.jpg
# /kaggle/input/image-data/RSICD_images/farmland_163.jpg
# /kaggle/input/image-data/RSICD_images/beach_125.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_29.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_134.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_136.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_158.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_202.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_31.jpg
# /kaggle/input/image-data/RSICD_images/playground_262.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_164.jpg
# /kaggle/input/image-data/RSICD_images/pond_176.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_17.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_197.jpg
# /kaggle/input/image-data/RSICD_images/commercial_104.jpg
# /kaggle/input/image-data/RSICD_images/port_145.jpg
# /kaggle/input/image-data/RSICD_images/airport_123.jpg
# /kaggle/input/image-data/RSICD_images/port_165.jpg
# /kaggle/input/image-data/RSICD_images/00691.jpg
# /kaggle/input/image-data/RSICD_images/00659.jpg
# /kaggle/input/image-data/RSICD_images/river_72.jpg
# /kaggle/input/image-data/RSICD_images/square_315.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_17.jpg
# /kaggle/input/image-data/RSICD_images/beach_218.jpg
# /kaggle/input/image-data/RSICD_images/desert_162.jpg
# /kaggle/input/image-data/RSICD_images/forest_179.jpg
# /kaggle/input/image-data/RSICD_images/playground_14.jpg
# /kaggle/input/image-data/RSICD_images/forest_8.jpg
# /kaggle/input/image-data/RSICD_images/farmland_309.jpg
# /kaggle/input/image-data/RSICD_images/00180.jpg
# /kaggle/input/image-data/RSICD_images/playground_282.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_139.jpg
# /kaggle/input/image-data/RSICD_images/mountain_122.jpg
# /kaggle/input/image-data/RSICD_images/bareland_85.jpg
# /kaggle/input/image-data/RSICD_images/beach_201.jpg
# /kaggle/input/image-data/RSICD_images/resort_250.jpg
# /kaggle/input/image-data/RSICD_images/church_162.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_18.jpg
# /kaggle/input/image-data/RSICD_images/bareland_33.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_92.jpg
# /kaggle/input/image-data/RSICD_images/stadium_51.jpg
# /kaggle/input/image-data/RSICD_images/river_346.jpg
# /kaggle/input/image-data/RSICD_images/desert_48.jpg
# /kaggle/input/image-data/RSICD_images/parking_277.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_381.jpg
# /kaggle/input/image-data/RSICD_images/square_129.jpg
# /kaggle/input/image-data/RSICD_images/00458.jpg
# /kaggle/input/image-data/RSICD_images/port_19.jpg
# /kaggle/input/image-data/RSICD_images/forest_198.jpg
# /kaggle/input/image-data/RSICD_images/port_78.jpg
# /kaggle/input/image-data/RSICD_images/desert_49.jpg
# /kaggle/input/image-data/RSICD_images/parking_268.jpg
# /kaggle/input/image-data/RSICD_images/school_104.jpg
# /kaggle/input/image-data/RSICD_images/industrial_191.jpg
# /kaggle/input/image-data/RSICD_images/00533.jpg
# /kaggle/input/image-data/RSICD_images/port_288.jpg
# /kaggle/input/image-data/RSICD_images/river_199.jpg
# /kaggle/input/image-data/RSICD_images/airport_55.jpg
# /kaggle/input/image-data/RSICD_images/mountain_98.jpg
# /kaggle/input/image-data/RSICD_images/playground_349.jpg
# /kaggle/input/image-data/RSICD_images/airport_53.jpg
# /kaggle/input/image-data/RSICD_images/church_88.jpg
# /kaggle/input/image-data/RSICD_images/port_14.jpg
# /kaggle/input/image-data/RSICD_images/beach_397.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_193.jpg
# /kaggle/input/image-data/RSICD_images/pond_26.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_306.jpg
# /kaggle/input/image-data/RSICD_images/church_193.jpg
# /kaggle/input/image-data/RSICD_images/00304.jpg
# /kaggle/input/image-data/RSICD_images/bridge_186.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_173.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_182.jpg
# /kaggle/input/image-data/RSICD_images/00096.jpg
# /kaggle/input/image-data/RSICD_images/park_91.jpg
# /kaggle/input/image-data/RSICD_images/beach_35.jpg
# /kaggle/input/image-data/RSICD_images/airport_121.jpg
# /kaggle/input/image-data/RSICD_images/school_172.jpg
# /kaggle/input/image-data/RSICD_images/mountain_246.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_75.jpg
# /kaggle/input/image-data/RSICD_images/airport_16.jpg
# /kaggle/input/image-data/RSICD_images/river_405.jpg
# /kaggle/input/image-data/RSICD_images/park_170.jpg
# /kaggle/input/image-data/RSICD_images/mountain_206.jpg
# /kaggle/input/image-data/RSICD_images/pond_12.jpg
# /kaggle/input/image-data/RSICD_images/mountain_96.jpg
# /kaggle/input/image-data/RSICD_images/parking_121.jpg
# /kaggle/input/image-data/RSICD_images/stadium_273.jpg
# /kaggle/input/image-data/RSICD_images/river_213.jpg
# /kaggle/input/image-data/RSICD_images/bridge_151.jpg
# /kaggle/input/image-data/RSICD_images/forest_221.jpg
# /kaggle/input/image-data/RSICD_images/park_42.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_315.jpg
# /kaggle/input/image-data/RSICD_images/00112.jpg
# /kaggle/input/image-data/RSICD_images/mountain_318.jpg
# /kaggle/input/image-data/RSICD_images/bareland_14.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_120.jpg
# /kaggle/input/image-data/RSICD_images/port_183.jpg
# /kaggle/input/image-data/RSICD_images/school_281.jpg
# /kaggle/input/image-data/RSICD_images/forest_188.jpg
# /kaggle/input/image-data/RSICD_images/industrial_288.jpg
# /kaggle/input/image-data/RSICD_images/pond_199.jpg
# /kaggle/input/image-data/RSICD_images/bareland_82.jpg
# /kaggle/input/image-data/RSICD_images/desert_160.jpg
# /kaggle/input/image-data/RSICD_images/industrial_291.jpg
# /kaggle/input/image-data/RSICD_images/resort_189.jpg
# /kaggle/input/image-data/RSICD_images/playground_368.jpg
# /kaggle/input/image-data/RSICD_images/meadow_207.jpg
# /kaggle/input/image-data/RSICD_images/bareland_194.jpg
# /kaggle/input/image-data/RSICD_images/resort_73.jpg
# /kaggle/input/image-data/RSICD_images/beach_10.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_302.jpg
# /kaggle/input/image-data/RSICD_images/center_211.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_228.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_288.jpg
# /kaggle/input/image-data/RSICD_images/commercial_29.jpg
# /kaggle/input/image-data/RSICD_images/parking_208.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_60.jpg
# /kaggle/input/image-data/RSICD_images/beach_19.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_179.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_272.jpg
# /kaggle/input/image-data/RSICD_images/pond_239.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_280.jpg
# /kaggle/input/image-data/RSICD_images/parking_9.jpg
# /kaggle/input/image-data/RSICD_images/mountain_148.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_235.jpg
# /kaggle/input/image-data/RSICD_images/stadium_38.jpg
# /kaggle/input/image-data/RSICD_images/square_220.jpg
# /kaggle/input/image-data/RSICD_images/farmland_315.jpg
# /kaggle/input/image-data/RSICD_images/park_228.jpg
# /kaggle/input/image-data/RSICD_images/resort_3.jpg
# /kaggle/input/image-data/RSICD_images/airport_88.jpg
# /kaggle/input/image-data/RSICD_images/00264.jpg
# /kaggle/input/image-data/RSICD_images/center_25.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_174.jpg
# /kaggle/input/image-data/RSICD_images/church_233.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_138.jpg
# /kaggle/input/image-data/RSICD_images/railwaystation_227.jpg
# /kaggle/input/image-data/RSICD_images/00040.jpg
# /kaggle/input/image-data/RSICD_images/port_33.jpg
# /kaggle/input/image-data/RSICD_images/beach_394.jpg
# /kaggle/input/image-data/RSICD_images/church_66.jpg
# /kaggle/input/image-data/RSICD_images/pond_75.jpg
# /kaggle/input/image-data/RSICD_images/commercial_100.jpg
# /kaggle/input/image-data/RSICD_images/park_189.jpg
# /kaggle/input/image-data/RSICD_images/stadium_197.jpg
# /kaggle/input/image-data/RSICD_images/00018.jpg
# /kaggle/input/image-data/RSICD_images/00319.jpg
# /kaggle/input/image-data/RSICD_images/commercial_228.jpg
# /kaggle/input/image-data/RSICD_images/airport_256.jpg
# /kaggle/input/image-data/RSICD_images/school_218.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_162.jpg
# /kaggle/input/image-data/RSICD_images/meadow_67.jpg
# /kaggle/input/image-data/RSICD_images/beach_247.jpg
# /kaggle/input/image-data/RSICD_images/industrial_354.jpg
# /kaggle/input/image-data/RSICD_images/sparseresidential_100.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_105.jpg
# /kaggle/input/image-data/RSICD_images/meadow_39.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_147.jpg
# /kaggle/input/image-data/RSICD_images/stadium_33.jpg
# /kaggle/input/image-data/RSICD_images/beach_105.jpg
# /kaggle/input/image-data/RSICD_images/park_72.jpg
# /kaggle/input/image-data/RSICD_images/river_137.jpg
# /kaggle/input/image-data/RSICD_images/square_62.jpg
# /kaggle/input/image-data/RSICD_images/industrial_145.jpg
# /kaggle/input/image-data/RSICD_images/center_255.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_114.jpg
# /kaggle/input/image-data/RSICD_images/baseballfield_108.jpg
# /kaggle/input/image-data/RSICD_images/storagetanks_39.jpg
# /kaggle/input/image-data/RSICD_images/industrial_10.jpg
# /kaggle/input/image-data/RSICD_images/airport_241.jpg
# /kaggle/input/image-data/RSICD_images/bareland_132.jpg
# /kaggle/input/image-data/RSICD_images/denseresidential_356.jpg
# /kaggle/input/image-data/RSICD_images/desert_122.jpg
# /kaggle/input/image-data/RSICD_images/church_155.jpg
# /kaggle/input/image-data/RSICD_images/pond_368.jpg
# /kaggle/input/image-data/RSICD_images/00222.jpg
# /kaggle/input/image-data/RSICD_images/mountain_249.jpg
# /kaggle/input/image-data/RSICD_images/pond_409.jpg
# /kaggle/input/image-data/RSICD_images/parking_159.jpg
# /kaggle/input/image-data/RSICD_images/pond_331.jpg
# /kaggle/input/image-data/RSICD_images/viaduct_142.jpg
# /kaggle/input/image-data/RSICD_images/port_149.jpg
# /kaggle/input/image-data/RSICD_images/playground_39.jpg
# /kaggle/input/image-data/RSICD_images/center_15.jpg
# /kaggle/input/image-data/RSICD_images/pond_294.jpg
# /kaggle/input/image-data/RSICD_images/commercial_240.jpg
# /kaggle/input/image-data/RSICD_images/river_211.jpg
# /kaggle/input/image-data/RSICD_images/park_311.jpg
# /kaggle/input/image-data/RSICD_images/industrial_125.jpg
# /kaggle/input/image-data/RSICD_images/bridge_246.jpg
# /kaggle/input/image-data/RSICD_images/00117.jpg
# /kaggle/input/image-data/RSICD_images/industrial_272.jpg
# /kaggle/input/image-data/RSICD_images/playground_60.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_172.jpg
# /kaggle/input/image-data/RSICD_images/bridge_350.jpg
# /kaggle/input/image-data/RSICD_images/mediumresidential_227.jpg

# %%
# Install missing packages
# !pip install rouge-score

# Download NLTK data
import nltk
nltk.download('wordnet', quiet=True)
nltk.download('punkt', quiet=True)
nltk.download('omw-1.4', quiet=True)
# Out:
# Requirement already satisfied: rouge-score in /usr/local/lib/python3.11/dist-packages (0.1.2)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.4.0)
# Requirement already satisfied: nltk in /usr/local/lib/python3.11/dist-packages (from rouge-score) (3.9.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.26.4)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.11/dist-packages (from rouge-score) (1.17.0)
# Requirement already satisfied: click in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (8.2.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (1.5.1)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (2024.11.6)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from nltk->rouge-score) (4.67.1)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (2025.2.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (2022.2.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->rouge-score) (2.4.1)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->rouge-score) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->rouge-score) (2022.2.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->rouge-score) (1.4.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->rouge-score) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->rouge-score) (2024.2.0)
# True

# %%
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from transformers import GPT2LMHeadModel, GPT2Tokenizer, ViTFeatureExtractor, ViTModel
import json
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from sklearn.model_selection import train_test_split
import os
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# Evaluation metrics
from nltk.translate.bleu_score import sentence_bleu, SmoothingFunction
from nltk.translate.meteor_score import meteor_score
from rouge_score import rouge_scorer
import nltk
nltk.download('wordnet', quiet=True)
nltk.download('punkt', quiet=True)

# Configuration
CONFIG = {
    'json_path': '/kaggle/input/json-data/dataset_rsicd.json',  # UPDATE THIS PATH
    'images_path': '/kaggle/input/image-data/RSICD_images',                # UPDATE THIS PATH
    'output_folder': 'results',
    'batch_size': 8,
    'learning_rate': 5e-5,  # Optimal learning rate
    'epochs': 15,
    'max_length': 50,
    'patience': 5
}

# Create output directory
os.makedirs(CONFIG['output_folder'], exist_ok=True)

# Dataset class
class CaptionDataset(Dataset):
    def __init__(self, data, img_dir, tokenizer, feature_extractor, max_len=50):
        self.data = data
        self.img_dir = img_dir
        self.tokenizer = tokenizer
        self.feature_extractor = feature_extractor
        self.max_len = max_len
        
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        item = self.data[idx]
        img_path = os.path.join(self.img_dir, item['filename'])
        
        # Load and process image
        try:
            image = Image.open(img_path).convert('RGB')
            img_features = self.feature_extractor(image, return_tensors="pt")['pixel_values'].squeeze(0)
        except Exception as e:
            print(f"Error loading image {img_path}: {e}")
            # Create dummy image if file not found
            img_features = torch.zeros(3, 224, 224)
        
        # Random caption selection
        caption = np.random.choice(item['sentences'])['raw']
        
        # Tokenize caption
        encoding = self.tokenizer(
            caption, 
            truncation=True, 
            padding='max_length', 
            max_length=self.max_len,
            return_tensors='pt'
        )
        
        return {
            'image': img_features,
            'input_ids': encoding['input_ids'].squeeze(0),
            'attention_mask': encoding['attention_mask'].squeeze(0),
            'caption': caption
        }

# ViT + GPT2 Model
class ViTGPT2CaptionModel(nn.Module):
    def __init__(self, gpt_model_name='gpt2', vit_model_name='google/vit-base-patch16-224'):
        super().__init__()
        print("Loading ViT model...")
        self.vit = ViTModel.from_pretrained(vit_model_name)
        print("Loading GPT2 model...")
        self.gpt2 = GPT2LMHeadModel.from_pretrained(gpt_model_name)
        
        # Projection layer to map ViT features to GPT2 embedding space
        self.projection = nn.Linear(self.vit.config.hidden_size, self.gpt2.config.n_embd)
        self.dropout = nn.Dropout(0.1)
        
        print(f"Model initialized: ViT hidden size: {self.vit.config.hidden_size}, GPT2 embedding size: {self.gpt2.config.n_embd}")
        
    def forward(self, images, input_ids, attention_mask):
        # Get image features from ViT
        img_outputs = self.vit(pixel_values=images)
        img_features = img_outputs.last_hidden_state.mean(dim=1)  # Global average pooling
        img_features = self.projection(img_features)
        img_features = self.dropout(img_features)
        
        # Get text embeddings from GPT2
        text_embeds = self.gpt2.transformer.wte(input_ids)
        
        # Combine image and text features
        img_features = img_features.unsqueeze(1)
        combined_embeds = torch.cat([img_features, text_embeds], dim=1)
        
        # Adjust attention mask for combined input
        img_mask = torch.ones(images.size(0), 1, device=attention_mask.device)
        combined_mask = torch.cat([img_mask, attention_mask], dim=1)
        
        # Create labels with padding for image token
        # Add -100 (ignore index) for the image token position
        img_labels = torch.full((images.size(0), 1), -100, device=input_ids.device)
        combined_labels = torch.cat([img_labels, input_ids], dim=1)
        
        # Forward through GPT2
        outputs = self.gpt2(inputs_embeds=combined_embeds, attention_mask=combined_mask, labels=combined_labels)
        return outputs

# Evaluation Metrics
def calculate_bleu_scores(references, hypotheses):
    """Calculate BLEU-1, BLEU-2, BLEU-3, BLEU-4"""
    smoothie = SmoothingFunction().method4
    bleu_scores = {}
    
    for n in [1, 2, 3, 4]:
        total_score = 0
        valid_pairs = 0
        for ref, hyp in zip(references, hypotheses):
            # Clean and validate text
            ref = ref.strip()
            hyp = hyp.strip()
            
            if len(ref) == 0 or len(hyp) == 0:
                continue
                
            ref_tokens = ref.split()
            hyp_tokens = hyp.split()
            
            if len(ref_tokens) == 0 or len(hyp_tokens) == 0:
                continue
                
            # BLEU weights for n-grams
            weights = [1.0/n] * n + [0.0] * (4-n)
            
            try:
                score = sentence_bleu([ref_tokens], hyp_tokens, weights=weights, smoothing_function=smoothie)
                total_score += score
                valid_pairs += 1
            except:
                continue
                
        bleu_scores[f'BLEU-{n}'] = total_score / max(valid_pairs, 1)
    
    return bleu_scores

def calculate_meteor_score(references, hypotheses):
    """Calculate METEOR score"""
    total_score = 0
    valid_pairs = 0
    
    for ref, hyp in zip(references, hypotheses):
        # Clean and validate text
        ref = ref.strip()
        hyp = hyp.strip()
        
        if len(ref) == 0 or len(hyp) == 0:
            continue
            
        ref_tokens = ref.split()
        hyp_tokens = hyp.split()
        
        if len(ref_tokens) == 0 or len(hyp_tokens) == 0:
            continue
            
        try:
            score = meteor_score([ref_tokens], hyp_tokens)
            total_score += score
            valid_pairs += 1
        except:
            continue
            
    return total_score / max(valid_pairs, 1)

def calculate_rouge_l(references, hypotheses):
    """Calculate ROUGE-L score"""
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    total_score = 0
    valid_pairs = 0
    
    for ref, hyp in zip(references, hypotheses):
        # Clean and validate text
        ref = ref.strip()
        hyp = hyp.strip()
        
        if len(ref) == 0 or len(hyp) == 0:
            continue
            
        try:
            score = scorer.score(ref, hyp)['rougeL'].fmeasure
            total_score += score
            valid_pairs += 1
        except:
            continue
            
    return total_score / max(valid_pairs, 1)

def calculate_cider_score(references, hypotheses):
    """Simplified CIDEr score"""
    # Using a combination of BLEU-4 and ROUGE-L as CIDEr approximation
    bleu_4_score = 0
    rouge_l_score = 0
    valid_pairs = 0
    
    smoothie = SmoothingFunction().method4
    scorer = rouge_scorer.RougeScorer(['rougeL'], use_stemmer=True)
    
    for ref, hyp in zip(references, hypotheses):
        ref = ref.strip()
        hyp = hyp.strip()
        
        if len(ref) == 0 or len(hyp) == 0:
            continue
            
        ref_tokens = ref.split()
        hyp_tokens = hyp.split()
        
        if len(ref_tokens) == 0 or len(hyp_tokens) == 0:
            continue
            
        try:
            # BLEU-4 component
            bleu_score = sentence_bleu([ref_tokens], hyp_tokens, weights=(0.25, 0.25, 0.25, 0.25), smoothing_function=smoothie)
            bleu_4_score += bleu_score
            
            # ROUGE-L component
            rouge_score = scorer.score(ref, hyp)['rougeL'].fmeasure
            rouge_l_score += rouge_score
            
            valid_pairs += 1
        except:
            continue
    
    if valid_pairs == 0:
        return 0.0
    
    # Combine BLEU-4 and ROUGE-L for CIDEr approximation
    return (bleu_4_score + rouge_l_score) / (2 * valid_pairs)

def calculate_spice_score(references, hypotheses):
    """Simplified SPICE score"""
    # Using METEOR as SPICE approximation (both focus on semantic similarity)
    return calculate_meteor_score(references, hypotheses)

def evaluate_all_metrics(references, hypotheses):
    """Calculate all evaluation metrics"""
    metrics = {}
    
    # BLEU scores
    bleu_scores = calculate_bleu_scores(references, hypotheses)
    metrics.update(bleu_scores)
    
    # Other metrics
    metrics['METEOR'] = calculate_meteor_score(references, hypotheses)
    metrics['ROUGE-L'] = calculate_rouge_l(references, hypotheses)
    metrics['CIDEr'] = calculate_cider_score(references, hypotheses)
    metrics['SPICE'] = calculate_spice_score(references, hypotheses)
    
    return metrics

def save_results(metrics_history, train_losses, val_losses, output_folder):
    """Save all results and plots"""
    
    # Save metrics to file
    with open(os.path.join(output_folder, 'metrics_history.json'), 'w') as f:
        json.dump(metrics_history, f, indent=2)
    
    # Save loss history
    loss_data = {
        'train_losses': train_losses,
        'val_losses': val_losses
    }
    with open(os.path.join(output_folder, 'loss_history.json'), 'w') as f:
        json.dump(loss_data, f, indent=2)
    
    # Plot and save loss curves
    plt.figure(figsize=(15, 10))
    
    # Loss curves
    plt.subplot(2, 3, 1)
    plt.plot(train_losses, label='Train Loss', color='blue')
    plt.plot(val_losses, label='Validation Loss', color='red')
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.title('Training and Validation Loss')
    plt.legend()
    plt.grid(True)
    
    # Accuracy curves (inverse of loss)
    plt.subplot(2, 3, 2)
    train_acc = [1/loss for loss in train_losses]
    val_acc = [1/loss for loss in val_losses]
    plt.plot(train_acc, label='Train Accuracy (1/Loss)', color='blue')
    plt.plot(val_acc, label='Val Accuracy (1/Loss)', color='red')
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.legend()
    plt.grid(True)
    
    # BLEU scores over time
    if metrics_history:
        epochs = list(range(1, len(metrics_history) + 1))
        plt.subplot(2, 3, 3)
        for bleu_n in ['BLEU-1', 'BLEU-2', 'BLEU-3', 'BLEU-4']:
            scores = [epoch_metrics[bleu_n] for epoch_metrics in metrics_history]
            plt.plot(epochs, scores, label=bleu_n)
        plt.xlabel('Epoch')
        plt.ylabel('BLEU Score')
        plt.title('BLEU Scores Over Time')
        plt.legend()
        plt.grid(True)
        
        # Other metrics
        plt.subplot(2, 3, 4)
        for metric in ['METEOR', 'ROUGE-L']:
            scores = [epoch_metrics[metric] for epoch_metrics in metrics_history]
            plt.plot(epochs, scores, label=metric)
        plt.xlabel('Epoch')
        plt.ylabel('Score')
        plt.title('METEOR and ROUGE-L Scores')
        plt.legend()
        plt.grid(True)
        
        plt.subplot(2, 3, 5)
        for metric in ['CIDEr', 'SPICE']:
            scores = [epoch_metrics[metric] for epoch_metrics in metrics_history]
            plt.plot(epochs, scores, label=metric)
        plt.xlabel('Epoch')
        plt.ylabel('Score')
        plt.title('CIDEr and SPICE Scores')
        plt.legend()
        plt.grid(True)
    
    plt.tight_layout()
    plt.savefig(os.path.join(output_folder, 'training_results.png'), dpi=300, bbox_inches='tight')
    plt.show()
    
    print(f"All results saved in '{output_folder}' folder")

# Main Training Function
def train_model():
    print("Starting Image Captioning Training with ViT + GPT2")
    print(f"Configuration: {CONFIG}")
    
    # Load dataset from JSON
    print(f"Loading dataset from: {CONFIG['json_path']}")
    with open(CONFIG['json_path'], 'r') as f:
        data = json.load(f)
    
    print(f"Total images in dataset: {len(data['images'])}")
    
    # Split dataset
    train_data, val_data = train_test_split(data['images'], test_size=0.2, random_state=42)
    print(f"Train samples: {len(train_data)}, Validation samples: {len(val_data)}")
    
    # Initialize tokenizer and feature extractor
    print("Loading tokenizer and feature extractor...")
    tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
    tokenizer.pad_token = tokenizer.eos_token
    feature_extractor = ViTFeatureExtractor.from_pretrained('google/vit-base-patch16-224')
    
    # Create datasets
    train_dataset = CaptionDataset(train_data, CONFIG['images_path'], tokenizer, feature_extractor, CONFIG['max_length'])
    val_dataset = CaptionDataset(val_data, CONFIG['images_path'], tokenizer, feature_extractor, CONFIG['max_length'])
    
    # Create data loaders
    train_loader = DataLoader(train_dataset, batch_size=CONFIG['batch_size'], shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=CONFIG['batch_size'], shuffle=False)
    
    # Initialize model
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    print(f"Using device: {device}")
    
    model = ViTGPT2CaptionModel().to(device)
    optimizer = torch.optim.AdamW(model.parameters(), lr=CONFIG['learning_rate'])
    
    # Training tracking
    train_losses, val_losses = [], []
    metrics_history = []
    best_val_loss = float('inf')
    patience_counter = 0
    
    print("Starting training...")
    
    # Training loop
    for epoch in range(CONFIG['epochs']):
        print(f"\nEpoch {epoch+1}/{CONFIG['epochs']}")
        
        # Training phase
        model.train()
        train_loss = 0
        train_pbar = tqdm(train_loader, desc='Training')
        
        for batch in train_pbar:
            optimizer.zero_grad()
            
            images = batch['image'].to(device)
            input_ids = batch['input_ids'].to(device)
            attention_mask = batch['attention_mask'].to(device)
            
            outputs = model(images, input_ids, attention_mask)
            loss = outputs.loss
            
            loss.backward()
            optimizer.step()
            
            train_loss += loss.item()
            train_pbar.set_postfix({'loss': loss.item()})
        
        train_loss /= len(train_loader)
        train_losses.append(train_loss)
        
        # Validation phase
        model.eval()
        val_loss = 0
        references, hypotheses = [], []
        
        val_pbar = tqdm(val_loader, desc='Validation')
        with torch.no_grad():
            for batch in val_pbar:
                images = batch['image'].to(device)
                input_ids = batch['input_ids'].to(device)
                attention_mask = batch['attention_mask'].to(device)
                
                outputs = model(images, input_ids, attention_mask)
                val_loss += outputs.loss.item()
                
                # Generate captions for evaluation
                img_features = model.vit(pixel_values=images).last_hidden_state.mean(dim=1)
                img_embeds = model.projection(img_features).unsqueeze(1)
                
                # Create attention mask for generation
                batch_size = images.size(0)
                attention_mask_gen = torch.ones(batch_size, 1, device=device)
                
                generated = model.gpt2.generate(
                    inputs_embeds=img_embeds,
                    attention_mask=attention_mask_gen,
                    max_length=30,  # Shorter for better quality
                    min_length=5,   # Minimum length
                    num_beams=5,    # More beams for better search
                    early_stopping=True,
                    pad_token_id=tokenizer.eos_token_id,
                    eos_token_id=tokenizer.eos_token_id,
                    do_sample=False,
                    repetition_penalty=1.2,  # Reduce repetition
                    length_penalty=1.0
                )
                
                for i, caption in enumerate(batch['caption']):
                    references.append(caption)
                    
                    # Decode and clean generated text
                    generated_text = tokenizer.decode(generated[i], skip_special_tokens=True).strip()
                    
                    # Handle empty generations
                    if len(generated_text) == 0:
                        generated_text = "empty"
                    
                    # Remove repetitive patterns
                    words = generated_text.split()
                    if len(words) > 3:
                        # Remove excessive repetition
                        cleaned_words = []
                        for word in words:
                            if len(cleaned_words) < 2 or word != cleaned_words[-1] or word != cleaned_words[-2]:
                                cleaned_words.append(word)
                        generated_text = " ".join(cleaned_words[:15])  # Max 15 words
                    
                    hypotheses.append(generated_text)
                
                val_pbar.set_postfix({'loss': outputs.loss.item()})
        
        val_loss /= len(val_loader)
        val_losses.append(val_loss)
        
        # Debug: Print some example generations
        print("\n--- Sample Generations ---")
        for i in range(min(3, len(references))):
            print(f"Reference: {references[i]}")
            print(f"Generated: {hypotheses[i]}")
            print("-" * 50)
        
        # Calculate evaluation metrics
        metrics = evaluate_all_metrics(references, hypotheses)
        metrics_history.append(metrics)
        
        # Print results
        print(f'Train Loss: {train_loss:.4f}, Val Loss: {val_loss:.4f}')
        print(f'BLEU-1: {metrics["BLEU-1"]:.4f}, BLEU-2: {metrics["BLEU-2"]:.4f}, BLEU-3: {metrics["BLEU-3"]:.4f}, BLEU-4: {metrics["BLEU-4"]:.4f}')
        print(f'METEOR: {metrics["METEOR"]:.4f}, ROUGE-L: {metrics["ROUGE-L"]:.4f}, CIDEr: {metrics["CIDEr"]:.4f}, SPICE: {metrics["SPICE"]:.4f}')
        print(f'Total references: {len(references)}, Total hypotheses: {len(hypotheses)}')
        
        # Early stopping and model saving
        if val_loss < best_val_loss:
            best_val_loss = val_loss
            model_path = os.path.join(CONFIG['output_folder'], 'best_model.pth')
            torch.save({
                'model_state_dict': model.state_dict(),
                'optimizer_state_dict': optimizer.state_dict(),
                'val_loss': val_loss,
                'epoch': epoch,
                'metrics': metrics
            }, model_path)
            print(f'Best model saved with validation loss: {val_loss:.4f}')
            patience_counter = 0
        else:
            patience_counter += 1
            if patience_counter >= CONFIG['patience']:
                print(f'Early stopping triggered at epoch {epoch+1}')
                break
    
    # Save all results
    save_results(metrics_history, train_losses, val_losses, CONFIG['output_folder'])
    
    print(f"\nTraining completed!")
    print(f"Best validation loss: {best_val_loss:.4f}")
    print(f"All results saved in '{CONFIG['output_folder']}' folder")

# Run training
if __name__ == "__main__":
    train_model()
# Out:
# Starting Image Captioning Training with ViT + GPT2
# Configuration: {'json_path': '/kaggle/input/json-data/dataset_rsicd.json', 'images_path': '/kaggle/input/image-data/RSICD_images', 'output_folder': 'results', 'batch_size': 8, 'learning_rate': 5e-05, 'epochs': 15, 'max_length': 50, 'patience': 5}
# Loading dataset from: /kaggle/input/json-data/dataset_rsicd.json
# Total images in dataset: 10921
# Train samples: 8736, Validation samples: 2185
# Loading tokenizer and feature extractor...
# Using device: cuda
# Loading ViT model...
# Some weights of ViTModel were not initialized from the model checkpoint at google/vit-base-patch16-224 and are newly initialized: ['pooler.dense.bias', 'pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Loading GPT2 model...
# Model initialized: ViT hidden size: 768, GPT2 embedding size: 768
# Starting training...
#
# Epoch 1/15
# Training: 100%|██████████| 1092/1092 [05:17<00:00,  3.44it/s, loss=0.481]
# Validation: 100%|██████████| 274/274 [02:20<00:00,  1.95it/s, loss=0.561]
# --- Sample Generations ---
# Reference: yellow beach is near a piece of green ocean with white waves .
# Generated: athewhiteyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellowyellow
# --------------------------------------------------
# Reference: five white storage tanks are near railways .
# Generated: amanyseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseverseversever
# --------------------------------------------------
# Reference: this is a lake in the city .
# Generated: amanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymanymany
# --------------------------------------------------
# Train Loss: 0.5591, Val Loss: 0.4304
# BLEU-1: 0.0000, BLEU-2: 0.0000, BLEU-3: 0.0000, BLEU-4: 0.0000
# METEOR: 0.0000, ROUGE-L: 0.0000, CIDEr: 0.0000, SPICE: 0.0000
# Total references: 2185, Total hypotheses: 2185
# Best model saved with validation loss: 0.4304
#
# Epoch 2/15
# Training:  24%|██▍       | 265/1092 [01:16<03:57,  3.48it/s, loss=0.401]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_100/2330822096.py in <cell line: 0>()
#     535 # Run training
#     536 if __name__ == "__main__":
# --> 537     train_model()
#
# /tmp/ipykernel_100/2330822096.py in train_model()
#     414             attention_mask = batch['attention_mask'].to(device)
#     415
# --> 416             outputs = model(images, input_ids, attention_mask)
#     417             loss = outputs.loss
#     418
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /tmp/ipykernel_100/2330822096.py in forward(self, images, input_ids, attention_mask)
#     119
#     120         # Forward through GPT2
# --> 121         outputs = self.gpt2(inputs_embeds=combined_embeds, attention_mask=combined_mask, labels=combined_labels)
#     122         return outputs
#     123
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, cache_position, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#    1208         return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1209
# -> 1210         transformer_outputs = self.transformer(
#    1211             input_ids,
#    1212             past_key_values=past_key_values,
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1737             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738         else:
# -> 1739             return self._call_impl(*args, **kwargs)
#    1740
#    1741     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1748                 or _global_backward_pre_hooks or _global_backward_hooks
#    1749                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750             return forward_call(*args, **kwargs)
#    1751
#    1752         result = None
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gpt2/modeling_gpt2.py in forward(self, input_ids, past_key_values, cache_position, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#     873         if attention_mask is not None and attention_mask.ndim < 4:
#     874             attention_mask = attention_mask.view(batch_size, -1)
# --> 875         causal_mask = self._update_causal_mask(
#     876             attention_mask, inputs_embeds, cache_position, past_key_values, output_attentions
#     877         )
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gpt2/modeling_gpt2.py in _update_causal_mask(self, attention_mask, input_tensor, cache_position, past_key_values, output_attentions)
#    1033
#    1034         # In case the provided `attention` mask is 2D, we generate a causal mask here (4D).
# -> 1035         causal_mask = self._prepare_4d_causal_attention_mask_with_cache_position(
#    1036             attention_mask,
#    1037             sequence_length=sequence_length,
#
# /usr/local/lib/python3.11/dist-packages/transformers/models/gpt2/modeling_gpt2.py in _prepare_4d_causal_attention_mask_with_cache_position(attention_mask, sequence_length, target_length, dtype, cache_position, batch_size, **kwargs)
#    1056         return causal_mask
#    1057
# -> 1058     @staticmethod
#    1059     def _prepare_4d_causal_attention_mask_with_cache_position(
#    1060         attention_mask: torch.Tensor,
#
# KeyboardInterrupt:
